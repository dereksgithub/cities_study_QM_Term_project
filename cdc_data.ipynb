# %% [markdown]
# ### CDC Data
#
# #### Part 1 Read the data and transform
# Added the CDC data to teh original research with data collected at the county level.
# Combined with other country-level indicators, this will provide more insights than aggregated city level indicators.
#
# PLACE Main Link:
# https://data.cdc.gov/browse?category=500+Cities+%26+Places
#
# link:
# for 2023:
# https://data.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-County-Data-20/swc5-untb/about_data
#
# for 2019:
# https://data.cdc.gov/500-Cities-Places/500-Cities-City-level-Data-GIS-Friendly-Format-201/dxpw-cm5u/about_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time
import datetime
import math
import pandas as pd
#from sklearn import preprocessing
#from sklearn.model_selection import train_test_split

# %%
# Read the Excel file from disk D located at: D:/OneDrive - University College London/T1/CASA0007/0. Research Project
place_20and21 = pd.read_csv(r"/mnt/d/OneDrive - University College London/T1/CASA0007/0. Research Project/PLACES__Local_Data_for_Better_Health__County_Data_2023_release_20240105.csv", encoding = "UTF-8")
# show df
#place_20and21.columns = city_df.iloc[0, :]

# Drop the second row
#place_20and21 = place_20and21.iloc[1:, :]

# %%
place_20and21
# Out:
#         Year StateAbbr      StateDesc LocationName DataSource  \
# 0       2021        GA        Georgia         Ware      BRFSS
# 1       2021        IN        Indiana         Ohio      BRFSS
# 2       2021        IN        Indiana         Owen      BRFSS
# 3       2021        IA           Iowa         Iowa      BRFSS
# 4       2021        IA           Iowa       Marion      BRFSS
# ...      ...       ...            ...          ...        ...
# 228765  2021        WA     Washington        Lewis      BRFSS
# 228766  2021        WI      Wisconsin         Door      BRFSS
# 228767  2021        WI      Wisconsin        Dodge      BRFSS
# 228768  2021        WV  West Virginia       Cabell      BRFSS
# 228769  2021        WV  West Virginia        Wayne      BRFSS
#
#                      Category  \
# 0             Health Outcomes
# 1             Health Outcomes
# 2             Health Outcomes
# 3             Health Outcomes
# 4             Health Outcomes
# ...                       ...
# 228765             Prevention
# 228766        Health Outcomes
# 228767  Health Risk Behaviors
# 228768             Disability
# 228769          Health Status
#
#                                                   Measure Data_Value_Unit  \
# 0                     Stroke among adults aged >=18 years               %
# 1                     Stroke among adults aged >=18 years               %
# 2                     Stroke among adults aged >=18 years               %
# 3                     Stroke among adults aged >=18 years               %
# 4                     Stroke among adults aged >=18 years               %
# ...                                                   ...             ...
# 228765  Current lack of health insurance among adults ...               %
# 228766            Depression among adults aged >=18 years               %
# 228767       Current smoking among adults aged >=18 years               %
# 228768  Cognitive disability among adults ages >=18 years               %
# 228769  Physical health not good for >=14 days among a...               %
#
#                 Data_Value_Type  Data_Value  ...  Data_Value_Footnote  \
# 0              Crude prevalence         4.6  ...                  NaN
# 1              Crude prevalence         3.8  ...                  NaN
# 2              Crude prevalence         4.0  ...                  NaN
# 3              Crude prevalence         3.3  ...                  NaN
# 4              Crude prevalence         3.0  ...                  NaN
# ...                         ...         ...  ...                  ...
# 228765         Crude prevalence         9.6  ...                  NaN
# 228766  Age-adjusted prevalence        22.0  ...                  NaN
# 228767         Crude prevalence        16.1  ...                  NaN
# 228768  Age-adjusted prevalence        18.4  ...                  NaN
# 228769  Age-adjusted prevalence        15.4  ...                  NaN
#
#         Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 0                        4.0                    5.1            36033
# 1                        3.3                    4.4             5978
# 2                        3.5                    4.6            21446
# 3                        2.8                    3.8            16568
# 4                        2.5                    3.5            33380
# ...                      ...                    ...              ...
# 228765                   7.5                   11.9            84398
# 228766                  18.1                   26.3            30369
# 228767                  12.8                   19.8            89313
# 228768                  15.4                   21.5            93418
# 228769                  13.1                   17.8            38498
#
#         LocationID  CategoryID   MeasureId DataValueTypeID  \
# 0            13299     HLTHOUT      STROKE          CrdPrv
# 1            18115     HLTHOUT      STROKE          CrdPrv
# 2            18119     HLTHOUT      STROKE          CrdPrv
# 3            19095     HLTHOUT      STROKE          CrdPrv
# 4            19125     HLTHOUT      STROKE          CrdPrv
# ...            ...         ...         ...             ...
# 228765       53041     PREVENT     ACCESS2          CrdPrv
# 228766       55029     HLTHOUT  DEPRESSION       AgeAdjPrv
# 228767       55027     RISKBEH    CSMOKING          CrdPrv
# 228768       54011     DISABLT   COGNITION       AgeAdjPrv
# 228769       54099    HLTHSTAT       PHLTH       AgeAdjPrv
#
#          Short_Question_Text                      Geolocation
# 0                     Stroke    POINT (-82.4215072 31.050881)
# 1                     Stroke    POINT (-84.9642994 38.940527)
# 2                     Stroke   POINT (-86.8388453 39.3173394)
# 3                     Stroke   POINT (-92.0591226 41.6839184)
# 4                     Stroke   POINT (-93.0938678 41.3314327)
# ...                      ...                              ...
# 228765      Health Insurance  POINT (-122.3774443 46.5800714)
# 228766            Depression   POINT (-87.0486828 45.0934165)
# 228767       Current Smoking   POINT (-88.7019394 43.4296276)
# 228768  Cognitive Disability   POINT (-82.2433966 38.4195778)
# 228769       Physical Health   POINT (-82.4226659 38.1436416)
#
# [228770 rows x 21 columns]

# %% [markdown]
# pivot tables:

# %%
pivot_df = place_20and21.pivot_table('Data_Value',['Year', 'StateAbbr', 'LocationName'], 'Measure')
pivot_df
# Out:
# Measure                        All teeth lost among adults aged >=65 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                        16.95
#                Aleutians West                                        12.05
#                Anchorage                                              9.75
#                Bethel                                                28.05
#                Bristol Bay                                           11.75
# ...                                                                    ...
# 2021 WY        Sweetwater                                              NaN
#                Teton                                                   NaN
#                Uinta                                                   NaN
#                Washakie                                                NaN
#                Weston                                                  NaN
#
# Measure                        Any disability among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                          NaN
#                Aleutians West                                          NaN
#                Anchorage                                               NaN
#                Bethel                                                  NaN
#                Bristol Bay                                             NaN
# ...                                                                    ...
# 2021 WY        Sweetwater                                            29.00
#                Teton                                                 21.25
#                Uinta                                                 29.35
#                Washakie                                              30.10
#                Weston                                                30.80
#
# Measure                        Arthritis among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                     NaN
#                Aleutians West                                     NaN
#                Anchorage                                          NaN
#                Bethel                                             NaN
#                Bristol Bay                                        NaN
# ...                                                               ...
# 2021 WY        Sweetwater                                       22.60
#                Teton                                            20.50
#                Uinta                                            23.00
#                Washakie                                         25.45
#                Weston                                           25.25
#
# Measure                        Binge drinking among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                          NaN
#                Aleutians West                                          NaN
#                Anchorage                                               NaN
#                Bethel                                                  NaN
#                Bristol Bay                                             NaN
# ...                                                                    ...
# 2021 WY        Sweetwater                                            17.35
#                Teton                                                 19.70
#                Uinta                                                 16.00
#                Washakie                                              15.75
#                Weston                                                16.75
#
# Measure                        Cancer (excluding skin cancer) among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                   6.50
#                Teton                                                        6.55
#                Uinta                                                        6.75
#                Washakie                                                     7.50
#                Weston                                                       7.50
#
# Measure                        Cervical cancer screening among adult women aged 21-65 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                              68.35
#                Aleutians West                                              69.95
#                Anchorage                                                   78.15
#                Bethel                                                      72.45
#                Bristol Bay                                                 79.90
# ...                                                                          ...
# 2021 WY        Sweetwater                                                    NaN
#                Teton                                                         NaN
#                Uinta                                                         NaN
#                Washakie                                                      NaN
#                Weston                                                        NaN
#
# Measure                        Cholesterol screening among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                  79.10
#                Teton                                                       81.95
#                Uinta                                                       78.00
#                Washakie                                                    80.10
#                Weston                                                      78.55
#
# Measure                        Chronic kidney disease among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                   2.75
#                Teton                                                        2.40
#                Uinta                                                        2.75
#                Washakie                                                     3.10
#                Weston                                                       3.10
#
# Measure                        Chronic obstructive pulmonary disease among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                   6.55
#                Teton                                                        4.65
#                Uinta                                                        6.85
#                Washakie                                                     6.95
#                Weston                                                       7.80
#
# Measure                        Cognitive disability among adults ages >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                  12.95
#                Teton                                                        9.40
#                Uinta                                                       12.75
#                Washakie                                                    12.50
#                Weston                                                      13.20
#
# Measure                        ...  \
# Year StateAbbr LocationName    ...
# 2020 AK        Aleutians East  ...
#                Aleutians West  ...
#                Anchorage       ...
#                Bethel          ...
#                Bristol Bay     ...
# ...                            ...
# 2021 WY        Sweetwater      ...
#                Teton           ...
#                Uinta           ...
#                Washakie        ...
#                Weston          ...
#
# Measure                        Older adult men aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                              28.45
#                Aleutians West                                              32.55
#                Anchorage                                                   40.65
#                Bethel                                                      19.50
#                Bristol Bay                                                 33.10
# ...                                                                          ...
# 2021 WY        Sweetwater                                                    NaN
#                Teton                                                         NaN
#                Uinta                                                         NaN
#                Washakie                                                      NaN
#                Weston                                                        NaN
#
# Measure                        Older adult women aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening, and Mammogram past 2 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                              28.15
#                Aleutians West                                              30.50
#                Anchorage                                                   32.90
#                Bethel                                                      18.25
#                Bristol Bay                                                 30.00
# ...                                                                          ...
# 2021 WY        Sweetwater                                                    NaN
#                Teton                                                         NaN
#                Uinta                                                         NaN
#                Washakie                                                      NaN
#                Weston                                                        NaN
#
# Measure                        Physical health not good for >=14 days among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                  10.90
#                Teton                                                        8.20
#                Uinta                                                       10.95
#                Washakie                                                    11.10
#                Weston                                                      11.95
#
# Measure                        Self-care disability among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                   3.25
#                Teton                                                        2.35
#                Uinta                                                        3.30
#                Washakie                                                     3.40
#                Weston                                                       3.70
#
# Measure                        Sleeping less than 7 hours among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                              34.20
#                Aleutians West                                              33.95
#                Anchorage                                                   30.90
#                Bethel                                                      37.05
#                Bristol Bay                                                 32.10
# ...                                                                          ...
# 2021 WY        Sweetwater                                                    NaN
#                Teton                                                         NaN
#                Uinta                                                         NaN
#                Washakie                                                      NaN
#                Weston                                                        NaN
#
# Measure                        Stroke among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                  NaN
#                Aleutians West                                  NaN
#                Anchorage                                       NaN
#                Bethel                                          NaN
#                Bristol Bay                                     NaN
# ...                                                            ...
# 2021 WY        Sweetwater                                     2.70
#                Teton                                          2.20
#                Uinta                                          2.85
#                Washakie                                       3.05
#                Weston                                         3.25
#
# Measure                        Taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                  65.20
#                Teton                                                       63.85
#                Uinta                                                       64.95
#                Washakie                                                    68.15
#                Weston                                                      67.45
#
# Measure                        Vision disability among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                             NaN
#                Aleutians West                                             NaN
#                Anchorage                                                  NaN
#                Bethel                                                     NaN
#                Bristol Bay                                                NaN
# ...                                                                       ...
# 2021 WY        Sweetwater                                                4.35
#                Teton                                                     3.10
#                Uinta                                                     4.30
#                Washakie                                                  4.50
#                Weston                                                    4.75
#
# Measure                        Visits to dentist or dental clinic among adults aged >=18 years  \
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                              48.50
#                Aleutians West                                              55.55
#                Anchorage                                                   64.85
#                Bethel                                                      41.75
#                Bristol Bay                                                 59.25
# ...                                                                          ...
# 2021 WY        Sweetwater                                                    NaN
#                Teton                                                         NaN
#                Uinta                                                         NaN
#                Washakie                                                      NaN
#                Weston                                                        NaN
#
# Measure                        Visits to doctor for routine checkup within the past year among adults aged >=18 years
# Year StateAbbr LocationName
# 2020 AK        Aleutians East                                                NaN
#                Aleutians West                                                NaN
#                Anchorage                                                     NaN
#                Bethel                                                        NaN
#                Bristol Bay                                                   NaN
# ...                                                                          ...
# 2021 WY        Sweetwater                                                  70.35
#                Teton                                                       66.75
#                Uinta                                                       64.55
#                Washakie                                                    65.05
#                Weston                                                      67.75
#
# [6219 rows x 37 columns]

# %% [markdown]
# __Now merge the this dataset and the urban institute data by location:__

# %% [markdown]
# Store all the column names and check out how many columns:

# %%
df_colnames = place_20and21.columns
#len(df_colnames)

# %% [markdown]
# Show all the column names:

# %%
df_colnames
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'LocationID', 'CategoryID', 'MeasureId', 'DataValueTypeID',
#        'Short_Question_Text', 'Geolocation'],
#       dtype='object')

# %% [markdown]
# Show all the health indicators, we can see 37 of them.
# These are suppose to be the columns with all counties, i.e. 1841 rows.
# Thus, some transformation are needed for the dataset.

# %%
len(place_20and21['Measure'].unique())
# Out:
# 37

# %%
len(place_20and21['LocationName'].unique())
# Out:
# 1841

# %% [markdown]
# #### Part 2 Data Transformation

# %% [markdown]
# This only shows

# %% [markdown]
# #### Part 3 Basic Statistical Analysis

# %% [markdown]
# #### Part 4 Clustering and Investigating Key Health Indicators

# %% [markdown]
# #### Part 5 Cluster Result Evaluation and PCA
